# %%
import json, time, requests, pandas as pd
from pathlib import Path
from urllib.parse import urlencode

# %%
KEY_CANDIDATES = ["api_key", "api_key.txt", "omdb_apikey.txt"]
key_path = next((Path(p) for p in KEY_CANDIDATES if Path(p).exists()), None)

if key_path is None:
    raise FileNotFoundError(
        f"Couldn't find any of {KEY_CANDIDATES}. "
        "Create one, paste your OMDb key on a single line, and re-run."
    )

OMDB_KEY = key_path.read_text(encoding="utf-8").strip()
if not OMDB_KEY or "REPLACE" in OMDB_KEY:
    raise ValueError("Your key file is empty or still a placeholder. Paste your real OMDb key.")
print(f"Loaded key from {key_path}")
# Out:
# Loaded key from api_key.txt

# %%
import requests, pandas as pd, json
from urllib.parse import urlencode

# assumes OMDB_KEY is already loaded
def omdb_search(keyword, typ="movie", year=None, max_pages=100):
    """
    Searches OMDb for a keyword and combines multiple pages of results.
    Each page contains up to 10 results. max_pages can go up to 100.
    """
    all_results = []
    
    for page in range(1, max_pages + 1):
        params = {"apikey": OMDB_KEY, "s": keyword, "type": typ, "page": page, "r": "json"}
        if year:
            params["y"] = str(year)
        url = f"http://www.omdbapi.com/?{urlencode(params)}"
        
        r = requests.get(url, timeout=15)
        data = r.json()
        
        if data.get("Response") != "True":
            print(f"Stopped at page {page}: {data.get('Error')}")
            break
        
        all_results.extend(data["Search"])
    
    if not all_results:
        print("❌ No results found.")
        return pd.DataFrame()
    
    df = pd.DataFrame(all_results)
    print(f"✅ Retrieved {len(df)} total results for '{keyword}'")
    return df

# Example use
df_search = omdb_search("2020", typ="movie", max_pages=100)  # 5 pages = up to 50 results
df_search.head()
# Out:
# Stopped at page 99: Movie not found!
# ✅ Retrieved 977 total results for '2020'
#                      Title  Year      imdbID   Type  \
# 0            Death to 2020  2020  tt13567480  movie
# 1  Life of Crime 1984-2020  2021  tt15119154  movie
# 2             Mission 2020  2021  tt15840328  movie
# 3             2020 Golmaal  2022  tt18246372  movie
# 4                     2020  2017   tt6727598  movie
#
#                                               Poster
# 0  https://m.media-amazon.com/images/M/MV5BOTkzZj...
# 1  https://m.media-amazon.com/images/M/MV5BODIzOG...
# 2  https://m.media-amazon.com/images/M/MV5BODQ5NT...
# 3  https://m.media-amazon.com/images/M/MV5BOTdlNz...
# 4  https://m.media-amazon.com/images/M/MV5BMjY4NG...

# %%
def omdb_by_id(imdb_id):
    url = f"http://www.omdbapi.com/?apikey={OMDB_KEY}&i={imdb_id}&r=json"
    r = requests.get(url, timeout=15)
    return r.json()

# which columns to keep from the detailed response
KEEP = [
    "Title","Year","Rated","Released","Runtime","Genre","Director","Writer","Actors",
    "Plot","Language","Country","Awards","Poster","Ratings","Metascore","imdbRating",
    "imdbVotes","imdbID","Type","DVD","BoxOffice","Production","Website"
]

# fetch details for each id from the search
details = []
for mid in df_search["imdbID"]:
    d = omdb_by_id(mid)
    if d.get("Response") == "True":
        details.append({k: d.get(k) for k in KEEP})

df_full = pd.DataFrame(details)
df_full.shape, df_full.columns.to_list()[:10]  # quick peek at size & some columns
# Out:
# ((901, 24),
#  ['Title',
#   'Year',
#   'Rated',
#   'Released',
#   'Runtime',
#   'Genre',
#   'Director',
#   'Writer',
#   'Actors',
#   'Plot'])

# %%
pd.options.display.max_columns = 50        # show more columns
pd.options.display.max_colwidth = 200      # don't truncate long text as much
pd.options.display.width = 0               # let Jupyter wrap nicely

df_full.head(3)                           # show first 10 with many columns
# Out:
#                      Title  Year  Rated     Released  Runtime  \
# 0            Death to 2020  2020  TV-MA  27 Dec 2020   70 min
# 1  Life of Crime 1984-2020  2021    N/A  30 Nov 2021  121 min
# 2             Mission 2020  2021    N/A  29 Oct 2021  140 min
#
#                            Genre                    Director  \
# 0                         Comedy  Al Campbell, Alice Mathias
# 1  Documentary, Biography, Crime                  Jon Alpert
# 2                         Action            Karanam P. Babji
#
#                                       Writer  \
# 0  Charlie Brooker, Annabel Jones, Tom Baker
# 1                                        N/A
# 2                                        N/A
#
#                                        Actors  \
# 0  Samuel L. Jackson, Hugh Grant, Lisa Kudrow
# 1                     Deliris, Freddy, Robert
# 2    Naga Babu, Naveen Chandra, Madhu Nambiar
#
#                                                                                                                                                                                       Plot  \
# 0  In mockumentary format, characters discuss events of 2020 with a mixture of true information and satire. The overarching topic is the COVID-19 pandemic, particularly in the US and UK.
# 1                       A relentless ride through the streets and prisons of Newark, New Jersey's largest city, and desperate fight to survive the deadliest enemy ever to attack America.
# 2                                 The film revolves around Prakash and his four friends, they get addicted to watching porn videos. In that daze, they rape their own college mate Swathi.
#
#   Language                                 Country              Awards  \
# 0  English  United States, Germany, United Kingdom  1 nomination total
# 1  English                           United States       2 nominations
# 2   Telugu                                   India                 N/A
#
#                                                                                                                                Poster  \
# 0                  https://m.media-amazon.com/images/M/MV5BOTkzZjY3ZWEtYWEzMy00YmI0LWE5YzMtZTRiNWVmZWIwOTY2XkEyXkFqcGc@._V1_SX300.jpg
# 1                  https://m.media-amazon.com/images/M/MV5BODIzOGNmODEtYzA5OS00MWJiLTkyOGEtYmMyNTQwN2MzMTY5XkEyXkFqcGc@._V1_SX300.jpg
# 2  https://m.media-amazon.com/images/M/MV5BODQ5NTBlMzUtOTdlOC00MDVjLWI3OTEtN2YwODg4OTA5YTVlXkEyXkFqcGdeQXVyMTQyOTI4MDYx._V1_SX300.jpg
#
#                                                                                                      Ratings  \
# 0  [{'Source': 'Internet Movie Database', 'Value': '6.8/10'}, {'Source': 'Rotten Tomatoes', 'Value': '45%'}]
# 1                                                 [{'Source': 'Internet Movie Database', 'Value': '8.4/10'}]
# 2                                                 [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}]
#
#   Metascore imdbRating imdbVotes      imdbID   Type  DVD BoxOffice Production  \
# 0       N/A        6.8    40,691  tt13567480  movie  N/A       N/A        N/A
# 1       N/A        8.4     2,826  tt15119154  movie  N/A       N/A        N/A
# 2       N/A        7.8     2,189  tt15840328  movie  N/A       N/A        N/A
#
#   Website
# 0     N/A
# 1     N/A
# 2     N/A

# %%
df_full.to_csv("omdb_details_sample.csv", index=False)
print("Saved omdb_details_sample.csv with", len(df_full), "rows")
# Out:
# Saved omdb_details_sample.csv with 901 rows

# %%
df_full.shape
# Out:
# (901, 24)
