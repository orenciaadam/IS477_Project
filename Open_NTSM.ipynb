# %%
import pandas as pd
df = pd.read_csv("Netflix_TV_Shows_and_Movies.csv")
df.shape
# Out:
# (5283, 11)

# %%
imdb_value = "tt13567480"   # replace with desired IMDb ID
filtered_df = df[df["imdb_id"] == imdb_value]
filtered_df
# Out:
#       index        id          title   type  \
# 3427   3427  tm981451  Death to 2020  MOVIE
#
#                                             description  release_year  \
# 3427  2020: A year so [insert adjective of choice he...          2020
#
#      age_certification  runtime     imdb_id  imdb_score  imdb_votes
# 3427               NaN       71  tt13567480         6.8     38301.0

# %%
min_year = df["release_year"].min()
max_year = df["release_year"].max()

print(f"Release year range: {min_year} to {max_year}")
# Out:
# Release year range: 1953 to 2022

# %%
unique_ids = sorted(df["imdb_id"].unique())
print(unique_ids)
# Out:
# ['tt0044429', 'tt0047673', 'tt0049761', 'tt0051390', 'tt0054953', 'tt0056379', 'tt0057357', 'tt0058385', 'tt0060104', 'tt0060862', 'tt0061418', 'tt0063929', 'tt0064842', 'tt0066999', 'tt0068562', 'tt0069049', 'tt0070047', 'tt0071811', 'tt0071853', 'tt0072584', 'tt0074168', 'tt0075314', 'tt0077751', 'tt0079470', 'tt0079749', 'tt0079807', 'tt0079833', 'tt0080453', 'tt0080653', 'tt0081071', 'tt0081848', 'tt0082329', 'tt0083437', 'tt0083564', 'tt0084042', 'tt0084352', 'tt0084492', 'tt0085333', 'tt0086815', 'tt0087800', 'tt0087843', 'tt0089108', 'tt0090589', 'tt0091106', 'tt0091939', 'tt0092005', 'tt0092099', 'tt0092948', 'tt0093058', 'tt0094052', 'tt0094478', 'tt0095262', 'tt0095945', 'tt0096179', 'tt0096286', 'tt0096643', 'tt0096694', 'tt0097926', 'tt0098084', 'tt0098237', 'tt0098635', 'tt0098904', 'tt0098999', 'tt0099077', 'tt0099429', 'tt0099833', 'tt0099858', 'tt0100758', 'tt0100848', 'tt0102058', 'tt0102227', 'tt0102492', 'tt0102537', 'tt0103060', 'tt0103123', 'tt0105265', 'tt0106064', 'tt0106145', 'tt0106206', 'tt0106582', 'tt0106655', 'tt0106701', 'tt0106965', 'tt0107004', 'tt0107060', 'tt0107206', 'tt0107362', 'tt0107554', 'tt0108041', 'tt0108291', 'tt0108308', 'tt0108800', 'tt0108847', 'tt0108927', 'tt0109134', 'tt0109830', 'tt0110076', 'tt0110222', 'tt0110367', 'tt0110545', 'tt0110657', 'tt0111780', 'tt0111987', 'tt0112159', 'tt0112553', 'tt0112851', 'tt0112916', 'tt0113280', 'tt0113481', 'tt0113957', 'tt0114031', 'tt0114214', 'tt0114231', 'tt0115275', 'tt0115895', 'tt0116483', 'tt0117057', 'tt0118480', 'tt0118615', 'tt0118971', 'tt0119008', 'tt0119013', 'tt0119177', 'tt0119345', 'tt0119629', 'tt0120102', 'tt0120177', 'tt0120201', 'tt0120611', 'tt0120685', 'tt0120746', 'tt0120815', 'tt0120873', 'tt0121164', 'tt0126234', 'tt0128853', 'tt0130018', 'tt0136153', 'tt0137100', 'tt0139872', 'tt0140399', 'tt0144214', 'tt0144701', 'tt0146838', 'tt0151121', 'tt0152183', 'tt0157132', 'tt0157183', 'tt0159382', 'tt0159510', 'tt0159511', 'tt0164052', 'tt0164212', 'tt0164538', 'tt0164550', 'tt0168366', 'tt0169102', 'tt0169599', 'tt0169858', 'tt0170416', 'tt0170799', 'tt0170803', 'tt0172234', 'tt0172493', 'tt0172684', 'tt0173554', 'tt0174852', 'tt0176095', 'tt0177505', 'tt0181739', 'tt0181852', 'tt0183686', 'tt0187393', 'tt0187738', 'tt0191182', 'tt0191397', 'tt0192087', 'tt0194542', 'tt0196229', 'tt0196291', 'tt0196355', 'tt0200353', 'tt0202477', 'tt0206921', 'tt0208903', 'tt0211634', 'tt0213338', 'tt0213363', 'tt0213984', 'tt0215129', 'tt0216817', 'tt0217085', 'tt0219432', 'tt0221027', 'tt0221344', 'tt0221735', 'tt0222270', 'tt0222518', 'tt0230412', 'tt0233856', 'tt0235918', 'tt0237395', 'tt0238784', 'tt0239195', 'tt0239495', 'tt0239682', 'tt0243174', 'tt0243585', 'tt0245674', 'tt0247102', 'tt0248012', 'tt0248126', 'tt0249934', 'tt0251160', 'tt0252503', 'tt0253867', 'tt0257044', 'tt0259057', 'tt0262158', 'tt0267130', 'tt0267804', 'tt0268639', 'tt0270053', 'tt0272397', 'tt0274428', 'tt0277027', 'tt0277371', 'tt0281491', 'tt0282003', 'tt0283770', 'tt0284770', 'tt0285823', 'tt0286907', 'tt0287570', 'tt0289649', 'tt0290223', 'tt0290988', 'tt0292490', 'tt0294149', 'tt0294967', 'tt0297241', 'tt0298130', 'tt0301231', 'tt0305727', 'tt0307403', 'tt0312528', 'tt0312859', 'tt0314331', 'tt0314353', 'tt0315642', 'tt0316472', 'tt0319020', 'tt0319061', 'tt0319736', 'tt0320024', 'tt0322645', 'tt0322802', 'tt0323013', 'tt0324216', 'tt0325710', 'tt0328962', 'tt0329101', 'tt0329829', 'tt0331370', 'tt0332902', 'tt0335438', 'tt0337741', 'tt0337926', 'tt0339968', 'tt0340770', 'tt0340855', 'tt0341957', 'tt0346631', 'tt0346723', 'tt0347304', 'tt0347473', 'tt0348662', 'tt0353049', 'tt0355119', 'tt0356470', 'tt0358053', 'tt0359013', 'tt0362120', 'tt0362771', 'tt0363282', 'tt0364751', 'tt0364845', 'tt0365545', 'tt0365907', 'tt0366548', 'tt0366551', 'tt0366621', 'tt0367110', 'tt0367279', 'tt0367413', 'tt0367495', 'tt0367594', 'tt0368190', 'tt0369441', 'tt0369735', 'tt0373856', 'tt0373883', 'tt0376541', 'tt0377610', 'tt0379272', 'tt0381061', 'tt0382383', 'tt03841 ...

# %%
print(df.shape)
print(df.columns)
print(df.head(3))
# Out:
# (5283, 11)
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'imdb_id', 'imdb_score', 'imdb_votes'],
#       dtype='object')
#    index        id                            title   type  \
# 0      0   tm84618                      Taxi Driver  MOVIE
# 1      1  tm127384  Monty Python and the Holy Grail  MOVIE
# 2      2   tm70993                    Life of Brian  MOVIE
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
# 1  King Arthur, accompanied by his squire, recrui...          1975
# 2  Brian Cohen is an average young Jewish man, bu...          1979
#
#   age_certification  runtime    imdb_id  imdb_score  imdb_votes
# 0                 R      113  tt0075314         8.3    795222.0
# 1                PG       91  tt0071853         8.2    530877.0
# 2                 R       94  tt0079470         8.0    392419.0

# %%
df_clean = df[
    (df['imdb_id'].notna()) &
    (df['imdb_id'].astype(str).str.len() >= 7)
].copy()

df_clean['imdb_id'] = df_clean['imdb_id'].astype(str).str.strip()

# %%
df_clean
# Out:
#       index         id                               title   type  \
# 0         0    tm84618                         Taxi Driver  MOVIE
# 1         1   tm127384     Monty Python and the Holy Grail  MOVIE
# 2         2    tm70993                       Life of Brian  MOVIE
# 3         3   tm190788                        The Exorcist  MOVIE
# 4         4    ts22164        Monty Python's Flying Circus   SHOW
# ...     ...        ...                                 ...    ...
# 5278   5278  tm1040816         Momshies! Your Soul is Mine  MOVIE
# 5279   5279  tm1014599                           Fine Wine  MOVIE
# 5280   5280  tm1045018                               Clash  MOVIE
# 5281   5281  tm1098060                      Shadow Parties  MOVIE
# 5282   5282   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     A mentally unstable Vietnam War veteran works ...          1976
# 1     King Arthur, accompanied by his squire, recrui...          1975
# 2     Brian Cohen is an average young Jewish man, bu...          1979
# 3     12-year-old Regan MacNeil begins to adapt an e...          1973
# 4     A British sketch comedy series with the shows ...          1969
# ...                                                 ...           ...
# 5278  Three women with totally different lives accid...          2021
# 5279  A beautiful love story that can happen between...          2021
# 5280  A man from Nigeria returns to his family in Ca...          2021
# 5281  A family faces destruction in a long-running c...          2021
# 5282  With winter behind them, Bheem and his townspe...          2021
#
#      age_certification  runtime     imdb_id  imdb_score  imdb_votes
# 0                    R      113   tt0075314         8.3    795222.0
# 1                   PG       91   tt0071853         8.2    530877.0
# 2                    R       94   tt0079470         8.0    392419.0
# 3                    R      133   tt0070047         8.1    391942.0
# 4                TV-14       30   tt0063929         8.8     72895.0
# ...                ...      ...         ...         ...         ...
# 5278               NaN      108  tt14412240         5.8        26.0
# 5279               NaN      100  tt13857480         6.9        39.0
# 5280               NaN       88  tt14620732         6.5        32.0
# 5281               NaN      116  tt10168094         6.2         9.0
# 5282               NaN        0  tt13711094         8.8        16.0
#
# [5283 rows x 11 columns]

# %%
movies = df_clean[df_clean["type"] == "MOVIE"]
shows = df_clean[df_clean["type"] == "SHOW"]
unknown = df_clean[~df_clean["type"].isin(["MOVIE", "SHOW"])]
print(f"Number of movies: {len(movies)}")
print(f"Number of shows: {len(shows)}")
print(f"Number of unknown: {len(unknown)}")
# Out:
# Number of movies: 3407
# Number of shows: 1876
# Number of unknown: 0
